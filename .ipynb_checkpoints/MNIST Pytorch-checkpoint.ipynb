# %%
import torch
import torch.nn as nn
import torchvision
import torchvision.transforms as transforms
import gc
batch_size = 128
num_classes = 10
learning_rate = 0.01
num_epochs = 40

# %%
# Device configuration
device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')

# %%
#Loading the dataset and preprocessing
train_dataset = torchvision.datasets.FashionMNIST(root = './Fashiondata',
                                              train = True,
                                                  transform = transforms.Compose([
                                                          transforms.RandomHorizontalFlip(),
                                                          transforms.ToTensor(),
                                                          transforms.Normalize(mean = (0.1307,), std = (0.3081,))]),
                                                  download = True)

# %%
test_dataset = torchvision.datasets.FashionMNIST(root = './Fashiondata',
                                                  train = False,
                                                  transform = transforms.Compose([
                                                  transforms.ToTensor(),
                                                  transforms.Normalize(mean = (0.1325,), std = (0.3105,))]),)

# %%
train_loader = torch.utils.data.DataLoader(dataset = train_dataset,
                                           batch_size = batch_size,
                                           shuffle = True)

# %%
train = next(iter(train_loader))

# %%
train[0].shape
# Out:
# torch.Size([128, 1, 28, 28])

# %%
test_loader = torch.utils.data.DataLoader(dataset = test_dataset,
                                           batch_size = batch_size,
                                           shuffle = True)

# %%
#Defining the convolutional neural network
class ConvNeuralNet(nn.Module):
    def __init__(self, num_classes):
        super(ConvNeuralNet, self).__init__()
        self.layer1 = nn.Sequential(
            nn.Conv2d(1, 32, kernel_size=3, stride=1, padding=0),
            nn.ReLU(),
            nn.BatchNorm2d(32))
        self.layer2 = nn.Sequential(
            nn.Conv2d(32, 64, kernel_size=3, stride=1, padding=0),
            nn.ReLU(),
            nn.BatchNorm2d(64))
        self.layer3 = nn.Sequential(
            nn.Conv2d(64, 128, kernel_size=3, stride=1, padding=1),
            nn.ReLU(),
            nn.BatchNorm2d(128),
            nn.MaxPool2d(kernel_size=2, stride=2))
        self.layer4 = nn.Sequential(
            nn.Conv2d(128, 256, kernel_size=3, stride=1, padding=0),
            nn.ReLU(),
            nn.BatchNorm2d(256))
        self.layer5 = nn.Sequential(
            nn.Conv2d(256, 512, kernel_size=3, stride=1, padding=0),
            nn.ReLU(),
            nn.BatchNorm2d(512),
            nn.MaxPool2d(kernel_size=8, stride=1))
        self.fc = nn.Linear(512, num_classes)
    def forward(self, x):
        out = self.layer1(x)
        out = self.layer2(out)
        out = self.layer3(out)
        out = self.layer4(out)
        out = self.layer5(out)
        out = out.reshape(out.size(0), -1)
        out = self.fc(out)

        return out

# %%
#Creating the model
model = ConvNeuralNet( num_classes).to(device)

# %%
#Defining cost and optimizer
cost = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)  
loss_history = []

# %%
# Train the model
total_step = len(train_loader)
for epoch in range(num_epochs):
    for i, (images, labels) in enumerate(train_loader):  
        # Move tensors to the configured device
        images = images.to(device)
        labels = labels.to(device)
        
        # Forward pass
        outputs = model(images)
        loss = cost(outputs, labels)
        
        # Backward and optimize
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        gc.collect()
        if (i+1) % 100 == 0:
            print ('Epoch [{}/{}], Step [{}/{}], Loss: {:.4f}' 
                   .format(epoch+1, num_epochs, i+1, total_step, loss.item()))
            loss_history.append(loss)
        del images, labels, outputs, loss
        
    if((epoch+1) % 8 == 0):
        for param_group in optimizer.param_groups:
            param_group['lr'] = param_group['lr']/4

# %%
# Test the model
# In test phase, we don't need to compute gradients (for memory efficiency)
with torch.no_grad():
    correct = 0
    total = 0
    for images, labels in test_loader:
        images = images.to(device)
        labels = labels.to(device)
        outputs = model(images)
        _, predicted = torch.max(outputs.data, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()
        del images, labels, outputs
    print('Accuracy of the network on the 10000 test images: {} %'.format(100 * correct / total))

# %%
#Also checking the accuracy on training set
with torch.no_grad():
    correct = 0
    total = 0
    for images, labels in train_loader:
        images = images.to(device)
        labels = labels.to(device)
        outputs = model(images)
        _, predicted = torch.max(outputs.data, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()
        del images, labels, outputs
    print('Accuracy of the network on the 60000 train images: {} %'.format(100 * correct / total))

# %%
torch.save(model.state_dict(),'mnist.pth')

# %% [markdown]
# ## Getting dataset to test

# %%
import cv2
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
def getFrame(secm, video_name):
    vidcap.set(cv2.CAP_PROP_POS_MSEC,sec*1000)
    hasFrames,image = vidcap.read()
    #if hasFrames:
        #cv2.imwrite(video_name +"_image_"+str(count)+".jpg", image) 
        # save frame as JPG file
    return hasFrames, image

# %%
# %pylab inline
from fastai.vision import *
from pathlib import Path
import pandas as pd
import json
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
#Type the names of the file in here
video_files = ['Video_Stream.mp4']
width = 456
height = 256
dim = (width, height)
count_generated_files = []

for video in video_files:
    vidcap = cv2.VideoCapture(video)
    sec = 0
    frameRate = 1 #//Change the number of seconds per interval here
    count=0
    test_images = []
    hasFrames, image = getFrame(sec, video)
    while hasFrames:
        count = count + 1
        sec = sec + frameRate
        sec = round(sec, 2)
        image =  cv2.resize(image, dim, interpolation = cv2.INTER_AREA)
        test_images.append(np.mean(np.asarray(image), axis = 2))
        hasFrames, image = getFrame(sec, video)
    count_generated_files.append(count)

#print(count_generated_files, " frames from each video")

# %%
test_images = np.array(test_images)

# %%
test_images.shape
# Out:
# (1055, 256, 456)

# %%
imshow(test_images[9], cmap = 'gray')

# %%
pickle.dump(test_images, open( "test_images.p", "wb" ), protocol=4)

# %% [markdown]
# ## Make custom datasets

# %%
import pickle
import numpy as np
import torch
import torch.nn as nn
import torchvision
import torchvision.transforms as transforms
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
test_images = pickle.load( open( "test_images.p", "rb" ) )

# %%
from PIL import Image

# %%
from torch.utils import data as D

# %%
class ClothesDS(D.Dataset):
    """
    A customized data loader.
    """
    def __init__(self, image_df):
        self.image_df = image_df
        self.len = len(image_df)
    
    # You must override __getitem__ and __len__
    def __getitem__(self, index):
        """ Get a sample from the dataset"""
        one_image = self.image_df[index]
        one_image = one_image[:,100:356]
        one_image = Image.fromarray(one_image)
        one_image = one_image.resize((28,28), resample = Image.BILINEAR)
        one_image = np.asarray(one_image)
        one_image = one_image
        mean = 0.1307
        std = 0.3081
        one_image = (one_image-mean)/std
        imshow(one_image)
        plt.show()
        #print(torch.tensor(np.asarray(one_image)).shape)
        #normalizing
        
        return torch.tensor(np.asarray(one_image)).view(1,28,28)

    def __len__(self):
        """
        Total number of samples in the dataset
        """
        return self.len

# %%
test_dataset_base = ClothesDS(test_images)

# %%
cuda = torch.cuda.is_available()

# %%
kwargs = {'num_workers': 0, 'pin_memory': True} if cuda else {}
test_loader_base = torch.utils.data.DataLoader(test_dataset_base, batch_size=4, shuffle=False, **kwargs)

# %%
#for images in test_loader_base:
   # print(images.shape)

# %%
# Device configuration
device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')
num_classes = 10

# %%
model = ConvNeuralNet( num_classes).to(device)

# %%
model.load_state_dict(torch.load('mnist.pth'))
# Out:
# <All keys matched successfully>

# %%
model.eval()
# Out:
# ConvNeuralNet(
#   (layer1): Sequential(
#     (0): Conv2d(1, 32, kernel_size=(3, 3), stride=(1, 1))
#     (1): ReLU()
#     (2): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (layer2): Sequential(
#     (0): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1))
#     (1): ReLU()
#     (2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (layer3): Sequential(
#     (0): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU()
#     (2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (3): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (layer4): Sequential(
#     (0): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1))
#     (1): ReLU()
#     (2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (layer5): Sequential(
# ...

# %%
with torch.no_grad():
    for batch in enumerate(test_loader_base):
        images = batch[1].to(device)
        outputs = model(images)
        _, predicted = torch.max(outputs.data, 1)
        print(predicted)
# Out:
# tensor([8, 8, 8, 8], device='cuda:0')
# tensor([8, 2, 2, 8], device='cuda:0')
# tensor([8, 8, 2, 8], device='cuda:0')
# tensor([7, 7, 7, 7], device='cuda:0')
# tensor([8, 8, 8, 8], device='cuda:0')
# tensor([8, 8, 8, 8], device='cuda:0')
# tensor([8, 8, 8, 8], device='cuda:0')
# tensor([8, 8, 9, 8], device='cuda:0')
# tensor([8, 8, 8, 8], device='cuda:0')
# tensor([8, 8, 8, 8], device='cuda:0')
# tensor([8, 8, 8, 8], device='cuda:0')
# tensor([8, 8, 8, 8], device='cuda:0')
# tensor([8, 8, 8, 8], device='cuda:0')
# tensor([8, 8, 8, 8], device='cuda:0')
# tensor([8, 8, 8, 8], device='cuda:0')
# tensor([8, 8, 8, 8], device='cuda:0')
# tensor([8, 8, 8, 8], device='cuda:0')
# tensor([8, 8, 8, 8], device='cuda:0')
# tensor([8, 8, 8, 8], device='cuda:0')
# tensor([8, 8, 8, 8], device='cuda:0')
# tensor([8, 8, 8, 8], device='cuda:0')
# tensor([8, 8, 8, 8], device='cuda:0')
# tensor([8, 8, 8, 8], device='cuda:0')
# tensor([8, 8, 8, 8], device='cuda:0')
# tensor([8, 8, 8, 8], device='cuda:0')
# ...

# %%
for i in x.numpy():
    imshow(i.reshape(28,28))
    plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-81-0c354ec33e19> in <module>
# ----> 1 for i in x.numpy():
#       2     imshow(i.reshape(28,28))
#       3     plt.show()
#
# NameError: name 'x' is not defined

# %%
predicted = model(x.to(device)).detach().cpu().numpy()

# %%
for i in predicted:
    print(np.argmax(i))
# Out:
# 8
# 8
# 8
# 8
